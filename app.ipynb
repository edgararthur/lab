# %%
import pandas as pd
import numpy as np

# %%
data_ifcia = pd.read_csv('data/Transcript_IFCIA.csv')
n = 9
data1 = data_ifcia.iloc[n:, :]
data1
# Out:
#        Code                                              Title       CA  \
# 9      Code                                              Title       CA
# 10  CCN 322                               Research Methodology       32
# 11  CCN 324                                      Biostatistics  36.5 42
# 12  CCN 326                                    Basic Computing       35
# 13  CCN 328  Principles and practice of Critical Care Nursi...       36
# 14  CCN 330                  Critical Care Nursing Practice II       33
# 15  CCN 332    Applied Pharmacology in Critical Care Nursing I       28
# 16  CCN 334       Reflective Practice in Critical Care Nursing       36
# 17      NaN                                          GPA: 3.57      NaN
# 18      NaN                                         CGPA:3.714      NaN
# 19     Code                                              Title       CA
# 20  CCN 409   Applied Pharmacology in Critical Care Nursing II       12
# ...

# %%
# df1 = data_ifcia.iloc[:, [5]]
# df1
df1 = data1[10:18]
df1[' CR']
# Out:
# 19     CR
# 20      3
# 21      3
# 22      3
# 23      3
# 24      3
# 25      3
# 26      3
# Name:  CR, dtype: object

# %%
data_local = pd.read_csv('data/Transcript_LOCAL.csv')
data_local
# Out:
#         CODE                                              TITLE    CA   EXAM  \
# 0    CCN 319           Applied Anatomy in Critical Care Nursing  29.5     53
# 1    CCN 321        Applied Physiology in Critical Care Nursing    34     55
# 2    CCN 323                   Infection Prevention and Control    37     46
# 3    CCN 325                Patient Assessment and Monitoring I    24     47
# 4    CCN 327  Principles and Practice of Critical Care Nursi...    28     58
# 5    CCN 329                   Critical Care Nursing Practice I    31     55
# 6    CCN 331          Theoretical Basis of Professional Nursing    36     45
# 7        NaN                                                NaN   NaN    NaN
# 8   GPA:3.86                                          CGPA:3.86   NaN    NaN
# 9       CODE                                              TITLE    CA   EXAM
# 10   CCN 322                               Research Methodology    32     47
# ...

# %%
df2 = data_local[9:17]
df2['CREDIT']
# Out:
# 9     CREDIT
# 10         3
# 11         3
# 12         3
# 13         3
# 14         3
# 15         3
# 16         3
# Name: CREDIT, dtype: object

# %%
compare = df1[' CR'].equals(df2['CREDIT'])
compare
# Out:
# False
